# %% [markdown]
# <a href="https://colab.research.google.com/github/Kathireshpraveen/Neural-network/blob/main/Neutral_network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
import pandas as pd
import numpy as np
import sklearn
import matplotlib
import keras
import os
from keras.layers import Dense
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score
print('Python: {}'.format(sys.version))
print('Pandas: {}'.format(pd.__version__))
print('Numpy: {}'.format(np.__version__))
print('Sklearn: {}'.format(sklearn.__version__))
print('Matplotlib: {}'.format(matplotlib.__version__))
print('Keras: {}'.format(keras.__version__))
# Out:
# Python: 3.7.12 (default, Sep 10 2021, 00:21:48)
# [GCC 7.5.0]
# Pandas: 1.1.5
# Numpy: 1.19.5
# Sklearn: 1.0.1
# Matplotlib: 3.2.2
# Keras: 2.7.0

# %%
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix
import seaborn as sns

# %%
# read the csv
cleveland = pd.read_csv("/content/drive/MyDrive/dataset/heart.csv")

# %%
# print the shape of the DataFrame, so we can see how many examples we have
print( 'Shape of DataFrame: {}'.format(cleveland.shape))
print (cleveland.loc[1])
# Out:
# Shape of DataFrame: (303, 14)
# age          37.0
# sex           1.0
# cp            2.0
# trestbps    130.0
# chol        250.0
# fbs           0.0
# restecg       1.0
# thalach     187.0
# exang         0.0
# oldpeak       3.5
# slope         0.0
# ca            0.0
# thal          2.0
# target        1.0
# Name: 1, dtype: float64

# %%
# print the last twenty or so data points
cleveland.loc[280:]
# Out:
#      age  sex  cp  trestbps  chol  fbs  ...  exang  oldpeak  slope  ca  thal  target
# 280   42    1   0       136   315    0  ...      1      1.8      1   0     1       0
# 281   52    1   0       128   204    1  ...      1      1.0      1   0     0       0
# 282   59    1   2       126   218    1  ...      0      2.2      1   1     1       0
# 283   40    1   0       152   223    0  ...      0      0.0      2   0     3       0
# 284   61    1   0       140   207    0  ...      1      1.9      2   1     3       0
# 285   46    1   0       140   311    0  ...      1      1.8      1   2     3       0
# 286   59    1   3       134   204    0  ...      0      0.8      2   2     2       0
# 287   57    1   1       154   232    0  ...      0      0.0      2   1     2       0
# 288   57    1   0       110   335    0  ...      1      3.0      1   1     3       0
# 289   55    0   0       128   205    0  ...      1      2.0      1   1     3       0
# 290   61    1   0       148   203    0  ...      0      0.0      2   1     3       0
# 291   58    1   0       114   318    0  ...      0      4.4      0   3     1       0
# 292   58    0   0       170   225    1  ...      1      2.8      1   2     1       0
# 293   67    1   2       152   212    0  ...      0      0.8      1   0     3       0
# 294   44    1   0       120   169    0  ...      1      2.8      0   0     1       0
# 295   63    1   0       140   187    0  ...      1      4.0      2   2     3       0
# 296   63    0   0       124   197    0  ...      1      0.0      1   0     2       0
# 297   59    1   0       164   176    1  ...      0      1.0      1   2     1       0
# 298   57    0   0       140   241    0  ...      1      0.2      1   0     3       0
# 299   45    1   3       110   264    0  ...      0      1.2      1   0     3       0
# 300   68    1   0       144   193    1  ...      0      3.4      1   2     3       0
# 301   57    1   0       130   131    0  ...      1      1.2      1   1     3       0
# 302   57    0   1       130   236    0  ...      0      0.0      1   1     2       0
#
# [23 rows x 14 columns]

# %%
# remove missing data (indicated with a "?")
data = cleveland[~cleveland.isin(['?'])]
data.loc[280:]
# Out:
#      age  sex  cp  trestbps  chol  fbs  ...  exang  oldpeak  slope  ca  thal  target
# 280   42    1   0       136   315    0  ...      1      1.8      1   0     1       0
# 281   52    1   0       128   204    1  ...      1      1.0      1   0     0       0
# 282   59    1   2       126   218    1  ...      0      2.2      1   1     1       0
# 283   40    1   0       152   223    0  ...      0      0.0      2   0     3       0
# 284   61    1   0       140   207    0  ...      1      1.9      2   1     3       0
# 285   46    1   0       140   311    0  ...      1      1.8      1   2     3       0
# 286   59    1   3       134   204    0  ...      0      0.8      2   2     2       0
# 287   57    1   1       154   232    0  ...      0      0.0      2   1     2       0
# 288   57    1   0       110   335    0  ...      1      3.0      1   1     3       0
# 289   55    0   0       128   205    0  ...      1      2.0      1   1     3       0
# 290   61    1   0       148   203    0  ...      0      0.0      2   1     3       0
# 291   58    1   0       114   318    0  ...      0      4.4      0   3     1       0
# 292   58    0   0       170   225    1  ...      1      2.8      1   2     1       0
# 293   67    1   2       152   212    0  ...      0      0.8      1   0     3       0
# 294   44    1   0       120   169    0  ...      1      2.8      0   0     1       0
# 295   63    1   0       140   187    0  ...      1      4.0      2   2     3       0
# 296   63    0   0       124   197    0  ...      1      0.0      1   0     2       0
# 297   59    1   0       164   176    1  ...      0      1.0      1   2     1       0
# 298   57    0   0       140   241    0  ...      1      0.2      1   0     3       0
# 299   45    1   3       110   264    0  ...      0      1.2      1   0     3       0
# 300   68    1   0       144   193    1  ...      0      3.4      1   2     3       0
# 301   57    1   0       130   131    0  ...      1      1.2      1   1     3       0
# 302   57    0   1       130   236    0  ...      0      0.0      1   1     2       0
#
# [23 rows x 14 columns]

# %%
# drop rows with NaN values from DataFrame
data = data.dropna(axis=0)
data.loc[280:]
# Out:
#      age  sex  cp  trestbps  chol  fbs  ...  exang  oldpeak  slope  ca  thal  target
# 280   42    1   0       136   315    0  ...      1      1.8      1   0     1       0
# 281   52    1   0       128   204    1  ...      1      1.0      1   0     0       0
# 282   59    1   2       126   218    1  ...      0      2.2      1   1     1       0
# 283   40    1   0       152   223    0  ...      0      0.0      2   0     3       0
# 284   61    1   0       140   207    0  ...      1      1.9      2   1     3       0
# 285   46    1   0       140   311    0  ...      1      1.8      1   2     3       0
# 286   59    1   3       134   204    0  ...      0      0.8      2   2     2       0
# 287   57    1   1       154   232    0  ...      0      0.0      2   1     2       0
# 288   57    1   0       110   335    0  ...      1      3.0      1   1     3       0
# 289   55    0   0       128   205    0  ...      1      2.0      1   1     3       0
# 290   61    1   0       148   203    0  ...      0      0.0      2   1     3       0
# 291   58    1   0       114   318    0  ...      0      4.4      0   3     1       0
# 292   58    0   0       170   225    1  ...      1      2.8      1   2     1       0
# 293   67    1   2       152   212    0  ...      0      0.8      1   0     3       0
# 294   44    1   0       120   169    0  ...      1      2.8      0   0     1       0
# 295   63    1   0       140   187    0  ...      1      4.0      2   2     3       0
# 296   63    0   0       124   197    0  ...      1      0.0      1   0     2       0
# 297   59    1   0       164   176    1  ...      0      1.0      1   2     1       0
# 298   57    0   0       140   241    0  ...      1      0.2      1   0     3       0
# 299   45    1   3       110   264    0  ...      0      1.2      1   0     3       0
# 300   68    1   0       144   193    1  ...      0      3.4      1   2     3       0
# 301   57    1   0       130   131    0  ...      1      1.2      1   1     3       0
# 302   57    0   1       130   236    0  ...      0      0.0      1   1     2       0
#
# [23 rows x 14 columns]

# %%
# print the shape and data type of the dataframe
print(data.shape)
print(data.dtypes)
# Out:
# (303, 14)
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %%
# transform data to numeric to enable further analysis
data = data.apply(pd.to_numeric)
data.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %%
# print data characteristics, usings pandas built-in describe() function
data.describe()
# Out:
#               age         sex          cp  ...          ca        thal      target
# count  303.000000  303.000000  303.000000  ...  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  ...    0.729373    2.313531    0.544554
# std      9.082101    0.466011    1.032052  ...    1.022606    0.612277    0.498835
# min     29.000000    0.000000    0.000000  ...    0.000000    0.000000    0.000000
# 25%     47.500000    0.000000    0.000000  ...    0.000000    2.000000    0.000000
# 50%     55.000000    1.000000    1.000000  ...    0.000000    2.000000    1.000000
# 75%     61.000000    1.000000    2.000000  ...    1.000000    3.000000    1.000000
# max     77.000000    1.000000    3.000000  ...    4.000000    3.000000    1.000000
#
# [8 rows x 14 columns]

# %%
# plot histograms for each variable
data.hist(figsize = (12, 12))
plt.show()

# %%
pd.crosstab(data.age,data.target).plot(kind="bar",figsize=(20,6))
plt.title('Heart Disease Frequency for Ages')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.heatmap(data.corr(),annot=True,fmt='.1f')
plt.show()

# %%
age_unique=sorted(data.age.unique())
age_thalach_values=data.groupby('age')['thalach'].count().values
mean_thalach=[]
for i,age in enumerate(age_unique):
    mean_thalach.append(sum(data[data['age']==age].thalach)/age_thalach_values[i])
    
plt.figure(figsize=(10,5))
sns.pointplot(x=age_unique,y=mean_thalach,color='red',alpha=0.8)
plt.xlabel('Age',fontsize = 15,color='blue')
plt.xticks(rotation=45)
plt.ylabel('Thalach',fontsize = 15,color='blue')
plt.title('Age vs Thalach',fontsize = 15,color='blue')
plt.grid()
plt.show()

# %%
# At this moment we have a dataframe that contains all of the heart.csv data. However we need to
# Separate them to [X, Y]. Where our target labels are 'Y', and 'X' is our training data.
Y = data.target.values
X = data.drop(['target'], axis=1)

# Now split to train/test with 80% training data, and 20% test data.
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# Check dimensions of both sets.
print("Train Features Size:", X_train.shape)
print("Test Features Size:", X_test.shape)
print("Train Labels Size:", Y_train.shape)
print("Test Labels Size:", Y_test.shape)
# Out:
# Train Features Size: (242, 13)
# Test Features Size: (61, 13)
# Train Labels Size: (242,)
# Test Labels Size: (61,)

# %%
# Define a Neural Network Model

def NN_model(learning_rate):
    model = Sequential()
    model.add(Dense(32, input_dim=13, kernel_initializer='normal', activation='relu'))
    model.add(Dense(16, kernel_initializer='normal', activation='relu'))
    model.add(Dense(2, activation='softmax'))
    Adam(lr=learning_rate)
    model.compile(loss='sparse_categorical_crossentropy', optimizer='Adam', metrics=['accuracy'])
    return model

# %%
# Build a NN-model, and start training
learning_rate = 0.01
model = NN_model(learning_rate)
print(model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 32)                448
# _________________________________________________________________
# dense_4 (Dense)              (None, 16)                528
# _________________________________________________________________
# dense_5 (Dense)              (None, 2)                 34
# =================================================================
# Total params: 1,010
# Trainable params: 1,010
# Non-trainable params: 0
# _________________________________________________________________
# None
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
history = model.fit(X_train, Y_train, validation_data=(X_test, Y_test), epochs=100, batch_size=16, verbose=2)
# Out:
# Epoch 1/100
# 16/16 - 1s - loss: 0.7906 - accuracy: 0.5248 - val_loss: 0.6627 - val_accuracy: 0.6557
# Epoch 2/100
# 16/16 - 0s - loss: 0.6880 - accuracy: 0.5372 - val_loss: 0.6328 - val_accuracy: 0.5574
# Epoch 3/100
# 16/16 - 0s - loss: 0.6440 - accuracy: 0.6033 - val_loss: 0.5880 - val_accuracy: 0.7705
# Epoch 4/100
# 16/16 - 0s - loss: 0.6358 - accuracy: 0.6281 - val_loss: 0.5622 - val_accuracy: 0.8033
# Epoch 5/100
# 16/16 - 0s - loss: 0.6197 - accuracy: 0.6612 - val_loss: 0.5461 - val_accuracy: 0.8525
# Epoch 6/100
# 16/16 - 0s - loss: 0.6106 - accuracy: 0.6364 - val_loss: 0.5559 - val_accuracy: 0.7377
# Epoch 7/100
# 16/16 - 0s - loss: 0.6363 - accuracy: 0.6322 - val_loss: 0.5187 - val_accuracy: 0.8197
# Epoch 8/100
# 16/16 - 0s - loss: 0.5832 - accuracy: 0.6942 - val_loss: 0.5129 - val_accuracy: 0.8033
# Epoch 9/100
# 16/16 - 0s - loss: 0.6018 - accuracy: 0.6736 - val_loss: 0.5067 - val_accuracy: 0.7869
# Epoch 10/100
# 16/16 - 0s - loss: 0.6242 - accuracy: 0.6570 - val_loss: 0.6120 - val_accuracy: 0.6393
# Epoch 11/100
# 16/16 - 0s - loss: 0.6038 - accuracy: 0.6694 - val_loss: 0.5086 - val_accuracy: 0.7541
# Epoch 12/100
# 16/16 - 0s - loss: 0.5811 - accuracy: 0.7231 - val_loss: 0.5030 - val_accuracy: 0.7541
# Epoch 13/100
# 16/16 - 0s - loss: 0.6039 - accuracy: 0.6942 - val_loss: 0.5698 - val_accuracy: 0.6557
# Epoch 14/100
# 16/16 - 0s - loss: 0.6347 - accuracy: 0.6446 - val_loss: 0.4947 - val_accuracy: 0.7705
# Epoch 15/100
# 16/16 - 0s - loss: 0.5582 - accuracy: 0.7231 - val_loss: 0.4938 - val_accuracy: 0.7377
# Epoch 16/100
# 16/16 - 0s - loss: 0.5544 - accuracy: 0.7149 - val_loss: 0.5315 - val_accuracy: 0.7541
# Epoch 17/100
# 16/16 - 0s - loss: 0.5842 - accuracy: 0.6942 - val_loss: 0.4542 - val_accuracy: 0.8525
# Epoch 18/100
# 16/16 - 0s - loss: 0.5345 - accuracy: 0.7355 - val_loss: 0.4498 - val_accuracy: 0.8525
# Epoch 19/100
# 16/16 - 0s - loss: 0.5297 - accuracy: 0.7273 - val_loss: 0.4630 - val_accuracy: 0.8197
# Epoch 20/100
# 16/16 - 0s - loss: 0.5396 - accuracy: 0.7355 - val_loss: 0.5165 - val_accuracy: 0.7541
# Epoch 21/100
# 16/16 - 0s - loss: 0.5846 - accuracy: 0.6694 - val_loss: 0.4352 - val_accuracy: 0.8689
# Epoch 22/100
# 16/16 - 0s - loss: 0.5302 - accuracy: 0.7314 - val_loss: 0.4411 - val_accuracy: 0.8689
# Epoch 23/100
# 16/16 - 0s - loss: 0.5158 - accuracy: 0.7355 - val_loss: 0.4270 - val_accuracy: 0.8525
# Epoch 24/100
# 16/16 - 0s - loss: 0.5013 - accuracy: 0.7562 - val_loss: 0.4467 - val_accuracy: 0.8033
# Epoch 25/100
# 16/16 - 0s - loss: 0.5408 - accuracy: 0.7355 - val_loss: 0.4077 - val_accuracy: 0.8525
# Epoch 26/100
# 16/16 - 0s - loss: 0.5286 - accuracy: 0.7231 - val_loss: 0.4441 - val_accuracy: 0.8033
# Epoch 27/100
# 16/16 - 0s - loss: 0.5072 - accuracy: 0.7397 - val_loss: 0.5102 - val_accuracy: 0.7377
# Epoch 28/100
# 16/16 - 0s - loss: 0.5023 - accuracy: 0.7479 - val_loss: 0.3948 - val_accuracy: 0.8852
# Epoch 29/100
# 16/16 - 0s - loss: 0.4883 - accuracy: 0.7562 - val_loss: 0.4024 - val_accuracy: 0.8525
# Epoch 30/100
# 16/16 - 0s - loss: 0.4802 - accuracy: 0.7562 - val_loss: 0.3903 - val_accuracy: 0.8689
# Epoch 31/100
# 16/16 - 0s - loss: 0.4746 - accuracy: 0.7438 - val_loss: 0.4821 - val_accuracy: 0.7541
# Epoch 32/100
# 16/16 - 0s - loss: 0.4870 - accuracy: 0.7603 - val_loss: 0.3830 - val_accuracy: 0.8361
# Epoch 33/100
# 16/16 - 0s - loss: 0.4587 - accuracy: 0.7810 - val_loss: 0.4011 - val_accuracy: 0.8525
# Epoch 34/100
# 16/16 - 0s - loss: 0.4652 - accuracy: 0.7810 - val_loss: 0.3683 - val_accuracy: 0.8525
# Epoch 35/100
# 16/16 - 0s - loss: 0.5241 - accuracy: 0.7479 - val_loss: 0.4975 - val_accuracy: 0.7377
# Epoch 36/100
# 16/16 - 0s - loss: 0.4586 - accuracy: 0.8223 - val_loss: 0.4169 - val_accuracy: 0.8197
# Epoch 37/100
# 16/16 - 0s - loss: 0.4804 - accuracy: 0.7769 - val_loss: 0.3793 - val_accuracy: 0.8689
# Epoch 38/100
# 16/16 - 0s - loss: 0.4728 - accuracy: 0.7397 - val_loss: 0.3610 - val_accuracy: 0.8525
# Epoch 39/100
# 16/16 - 0s - loss: 0.4771 - accuracy: 0.7645 - val_loss: 0.3673 - val_accuracy: 0.8689
# Epoch 40/100
# 16/16 - 0s - loss: 0.4735 - accuracy: 0.7769 - val_loss: 0.3644 - val_accuracy: 0.8525
# Epoch 41/100
# 16/16 - 0s - loss: 0.4373 - accuracy: 0.8099 - val_loss: 0.3634 - val_accuracy: 0.8525
# Epoch 42/100
# 16/16 - 0s - loss: 0.4405 - accuracy: 0.7893 - val_loss: 0.3597 - val_accuracy: 0.8689
# Epoch 43/100
# 16/16 - 0s - loss: 0.4462 - accuracy: 0.8058 - val_loss: 0.3723 - val_accuracy: 0.8525
# Epoch 44/100
# 16/16 - 0s - loss: 0.4312 - accuracy: 0.8140 - val_loss: 0.3552 - val_accuracy: 0.8525
# Epoch 45/100
# 16/16 - 0s - loss: 0.4268 - accuracy: 0.8017 - val_loss: 0.4213 - val_accuracy: 0.8033
# Epoch 46/100
# 16/16 - 0s - loss: 0.4498 - accuracy: 0.7934 - val_loss: 0.4503 - val_accuracy: 0.8197
# Epoch 47/100
# 16/16 - 0s - loss: 0.4251 - accuracy: 0.8058 - val_loss: 0.4117 - val_accuracy: 0.8197
# Epoch 48/100
# 16/16 - 0s - loss: 0.4185 - accuracy: 0.8223 - val_loss: 0.3976 - val_accuracy: 0.8197
# Epoch 49/100
# 16/16 - 0s - loss: 0.4110 - accuracy: 0.8182 - val_loss: 0.3651 - val_accuracy: 0.8361
# Epoch 50/100
# 16/16 - 0s - loss: 0.4122 - accuracy: 0.8306 - val_loss: 0.3470 - val_accuracy: 0.8852
# Epoch 51/100
# 16/16 - 0s - loss: 0.4238 - accuracy: 0.8223 - val_loss: 0.3422 - val_accuracy: 0.8852
# Epoch 52/100
# 16/16 - 0s - loss: 0.4281 - accuracy: 0.7810 - val_loss: 0.3642 - val_accuracy: 0.8689
# Epoch 53/100
# 16/16 - 0s - loss: 0.4162 - accuracy: 0.8058 - val_loss: 0.3407 - val_accuracy: 0.8852
# Epoch 54/100
# 16/16 - 0s - loss: 0.4081 - accuracy: 0.8306 - val_loss: 0.3512 - val_accuracy: 0.8689
# Epoch 55/100
# 16/16 - 0s - loss: 0.3903 - accuracy: 0.8347 - val_loss: 0.3572 - val_accuracy: 0.8689
# Epoch 56/100
# 16/16 - 0s - loss: 0.3980 - accuracy: 0.8264 - val_loss: 0.3524 - val_accuracy: 0.8689
# Epoch 57/100
# 16/16 - 0s - loss: 0.4006 - accuracy: 0.8347 - val_loss: 0.3419 - val_accuracy: 0.8852
# Epoch 58/100
# 16/16 - 0s - loss: 0.3974 - accuracy: 0.8347 - val_loss: 0.3389 - val_accuracy: 0.8689
# Epoch 59/100
# 16/16 - 0s - loss: 0.4222 - accuracy: 0.8264 - val_loss: 0.3445 - val_accuracy: 0.8852
# Epoch 60/100
# 16/16 - 0s - loss: 0.4065 - accuracy: 0.8058 - val_loss: 0.3669 - val_accuracy: 0.8689
# Epoch 61/100
# 16/16 - 0s - loss: 0.3880 - accuracy: 0.8430 - val_loss: 0.4089 - val_accuracy: 0.8033
# Epoch 62/100
# 16/16 - 0s - loss: 0.3867 - accuracy: 0.8223 - val_loss: 0.3648 - val_accuracy: 0.8689
# Epoch 63/100
# 16/16 - 0s - loss: 0.3968 - accuracy: 0.8264 - val_loss: 0.4838 - val_accuracy: 0.7377
# Epoch 64/100
# 16/16 - 0s - loss: 0.3888 - accuracy: 0.8264 - val_loss: 0.3988 - val_accuracy: 0.8361
# Epoch 65/100
# 16/16 - 0s - loss: 0.3901 - accuracy: 0.8223 - val_loss: 0.3454 - val_accuracy: 0.8689
# Epoch 66/100
# 16/16 - 0s - loss: 0.3743 - accuracy: 0.8388 - val_loss: 0.3567 - val_accuracy: 0.8689
# Epoch 67/100
# 16/16 - 0s - loss: 0.4015 - accuracy: 0.8182 - val_loss: 0.3450 - val_accuracy: 0.8852
# Epoch 68/100
# 16/16 - 0s - loss: 0.4198 - accuracy: 0.8182 - val_loss: 0.3436 - val_accuracy: 0.8689
# Epoch 69/100
# 16/16 - 0s - loss: 0.3993 - accuracy: 0.8099 - val_loss: 0.3580 - val_accuracy: 0.8689
# Epoch 70/100
# 16/16 - 0s - loss: 0.4203 - accuracy: 0.8182 - val_loss: 0.3526 - val_accuracy: 0.8689
# Epoch 71/100
# 16/16 - 0s - loss: 0.4091 - accuracy: 0.7893 - val_loss: 0.3412 - val_accuracy: 0.8852
# Epoch 72/100
# 16/16 - 0s - loss: 0.3978 - accuracy: 0.8388 - val_loss: 0.3451 - val_accuracy: 0.8689
# Epoch 73/100
# 16/16 - 0s - loss: 0.4337 - accuracy: 0.7686 - val_loss: 0.3380 - val_accuracy: 0.8689
# Epoch 74/100
# 16/16 - 0s - loss: 0.3921 - accuracy: 0.8430 - val_loss: 0.3377 - val_accuracy: 0.8689
# Epoch 75/100
# 16/16 - 0s - loss: 0.4018 - accuracy: 0.8471 - val_loss: 0.3387 - val_accuracy: 0.8689
# Epoch 76/100
# 16/16 - 0s - loss: 0.3979 - accuracy: 0.8140 - val_loss: 0.3377 - val_accuracy: 0.8689
# Epoch 77/100
# 16/16 - 0s - loss: 0.4017 - accuracy: 0.8264 - val_loss: 0.3369 - val_accuracy: 0.8852
# Epoch 78/100
# 16/16 - 0s - loss: 0.3865 - accuracy: 0.8471 - val_loss: 0.3417 - val_accuracy: 0.8852
# Epoch 79/100
# 16/16 - 0s - loss: 0.4025 - accuracy: 0.8017 - val_loss: 0.3596 - val_accuracy: 0.8689
# Epoch 80/100
# 16/16 - 0s - loss: 0.4464 - accuracy: 0.8223 - val_loss: 0.3413 - val_accuracy: 0.8852
# Epoch 81/100
# 16/16 - 0s - loss: 0.3799 - accuracy: 0.8347 - val_loss: 0.3681 - val_accuracy: 0.8689
# Epoch 82/100
# 16/16 - 0s - loss: 0.3797 - accuracy: 0.8347 - val_loss: 0.3410 - val_accuracy: 0.8852
# Epoch 83/100
# 16/16 - 0s - loss: 0.3768 - accuracy: 0.8430 - val_loss: 0.3597 - val_accuracy: 0.8689
# Epoch 84/100
# 16/16 - 0s - loss: 0.3734 - accuracy: 0.8306 - val_loss: 0.3424 - val_accuracy: 0.8852
# Epoch 85/100
# 16/16 - 0s - loss: 0.4105 - accuracy: 0.8347 - val_loss: 0.4947 - val_accuracy: 0.7377
# Epoch 86/100
# 16/16 - 0s - loss: 0.4794 - accuracy: 0.7603 - val_loss: 0.3939 - val_accuracy: 0.8525
# Epoch 87/100
# 16/16 - 0s - loss: 0.4045 - accuracy: 0.8017 - val_loss: 0.3861 - val_accuracy: 0.8525
# Epoch 88/100
# 16/16 - 0s - loss: 0.3883 - accuracy: 0.8264 - val_loss: 0.3366 - val_accuracy: 0.8852
# Epoch 89/100
# 16/16 - 0s - loss: 0.3685 - accuracy: 0.8471 - val_loss: 0.4028 - val_accuracy: 0.8361
# Epoch 90/100
# 16/16 - 0s - loss: 0.3683 - accuracy: 0.8512 - val_loss: 0.3464 - val_accuracy: 0.8689
# Epoch 91/100
# 16/16 - 0s - loss: 0.3875 - accuracy: 0.8099 - val_loss: 0.3712 - val_accuracy: 0.8689
# Epoch 92/100
# 16/16 - 0s - loss: 0.4393 - accuracy: 0.8099 - val_loss: 0.3459 - val_accuracy: 0.8852
# Epoch 93/100
# 16/16 - 0s - loss: 0.4001 - accuracy: 0.7934 - val_loss: 0.3393 - val_accuracy: 0.8852
# Epoch 94/100
# 16/16 - 0s - loss: 0.3722 - accuracy: 0.8471 - val_loss: 0.3447 - val_accuracy: 0.8852
# Epoch 95/100
# 16/16 - 0s - loss: 0.3671 - accuracy: 0.8512 - val_loss: 0.3492 - val_accuracy: 0.8852
# Epoch 96/100
# 16/16 - 0s - loss: 0.3654 - accuracy: 0.8512 - val_loss: 0.3859 - val_accuracy: 0.8361
# Epoch 97/100
# 16/16 - 0s - loss: 0.3928 - accuracy: 0.8017 - val_loss: 0.3381 - val_accuracy: 0.8852
# Epoch 98/100
# 16/16 - 0s - loss: 0.3759 - accuracy: 0.8512 - val_loss: 0.3403 - val_accuracy: 0.8852
# Epoch 99/100
# 16/16 - 0s - loss: 0.3894 - accuracy: 0.8306 - val_loss: 0.3541 - val_accuracy: 0.8689
# Epoch 100/100
# 16/16 - 0s - loss: 0.3741 - accuracy: 0.8347 - val_loss: 0.3442 - val_accuracy: 0.8852

# %%
# Plot the model accuracy vs. number of Epochs
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Train', 'Test'])
plt.show()

# Plot the Loss function vs. number of Epochs
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['Train', 'Test'])
plt.show()

# %%
predictions = np.argmax(model.predict(X_test), axis=1)
model_accuracy = accuracy_score(Y_test, predictions)*100
print("Model Accracy:", model_accuracy,"%")
print(classification_report(Y_test, predictions))
# Out:
# Model Accracy: 88.52459016393442 %
#               precision    recall  f1-score   support
#
#            0       0.89      0.86      0.88        29
#            1       0.88      0.91      0.89        32
#
#     accuracy                           0.89        61
#    macro avg       0.89      0.88      0.88        61
# weighted avg       0.89      0.89      0.89        61
